# %% [markdown]
# # 30 REGULAR EXPRESSION EXERCISES!

# %% [markdown]
# Regex, you never know when they might come in handy. It's one of the "good programmer"'s fundamental yet a few people actually masters them.

# %%
import re

# %% [markdown]
# 1) Write a Python program to check that a string contains only a certain set of characters (in this case a-z, A-Z and 0-9).

# %%
# Solution
def is_allowed_specific_char(string):
  # Define a regex pattern
  pattern = r'^[A-Za-z0-9]+$'
  # Use the pattern to search for ....

  return re.search(pattern, string) != None
    
print(is_allowed_specific_char("ABCDEFabcdef123450")) # True
print(is_allowed_specific_char("*&%@#!}{")) # False
# Out:
# True
# False

# %% [markdown]
# 2) Write a Python program that matches a string that has an a followed by zero or more b's

# %%
# Solution
def text_match(text):
  return re.search(r"ab*", text) != None
  

print(text_match("ac"))   # Found a match!
print(text_match("abc"))  # Found a match!
print(text_match("abbc"))   # Found a match!
print(text_match("bbc"))  # Not matched
# Out:
# True
# True
# True
# False

# %% [markdown]
# 3) Write a Python program that matches a string that has an a followed by one or more b's

# %%
# Solution
def text_match(text):
  return re.search(r"ab+", text) != None

print(text_match("ab"))   # Found a match!
print(text_match("abc"))   # Found a match!
print(text_match("ac"))  # Not matched
print(text_match("bbc"))  # Not matched
# Out:
# True
# True
# False
# False

# %% [markdown]
# 4) Write a Python program that matches a string that has an a followed by zero or one 'b'

# %%
# Solution
def text_match(text):
  return re.search(r"ab?", text) != None
  
print(text_match("ab"))  # Found a match!
print(text_match("abc"))  # Found a match!
print(text_match("abbc"))  # Found a match!
print(text_match("aabbc"))  # Found a match!
print(text_match("ac"))  # Found a match!
print(text_match("bbc"))  # Not matched
# Out:
# True
# True
# True
# True
# True
# False

# %% [markdown]
# 5) Write a Python program that matches a string that has an a followed by three 'b'

# %%
# Solution
def text_match(text):
  return re.search(r"ab{3}", text) != None

print(text_match("abbb"))  # Found a match!
print(text_match("aabbbbbc"))  # Found a match!
print(text_match("aabbc"))  # Not matched
print(text_match("ac"))  # Not matched
print(text_match("bbc"))  # Not matched
# Out:
# True
# True
# False
# False
# False

# %% [markdown]
# 6) Write a Python program that matches a string that has an a followed by two to three 'b'.

# %%
# Solution
def text_match(text):
  return re.search(r"ab{2,3}", text) != None

print(text_match("ab"))  # Not matched
print(text_match("aabbbbbc"))  # Found a match!
print(text_match("aabbc"))  # Found a match!
print(text_match("ac"))  # Not matched
print(text_match("bbc"))  # Not matched
# Out:
# False
# True
# True
# False
# False

# %% [markdown]
# 7) Write a Python program to find sequences of lowercase letters joined with a underscore.

# %%
# Solution
def text_match(text):
  return re.search(r"^[a-z]+_[a-z]+$", text) != None

print(text_match("aab_cbbbc"))  # Found a match!
print(text_match("aab_Abbbc"))  # Not matched
print(text_match("Aaab_abbbc"))  # Not matched
# Out:
# True
# False
# False

# %% [markdown]
# 8) ..Write a Python program to find the sequences of one upper case letter followed by lower case letters.

# %%
# Solution
def text_match(text):
  return re.search(r"[A-Z][a-z]{2,}", text) != None

print(text_match("aab_cbbbc"))  # Not matched
print(text_match("aab_Abbbc"))  # Found a match!
print(text_match("Aaab_abbbc"))  # Found a match!
# Out:
# False
# True
# True

# %% [markdown]
# 9) Write a Python program that matches a string that has an 'a' followed by anything, ending in 'b'.

# %%
# Solution
def text_match(text):
  return re.search(r"a.*b$", text) != None

print(text_match("aabbbbd"))  # Not matched
print(text_match("aabAbbbc"))  # Not matched
print(text_match("accddbbjjjb"))  # Found a match!
# Out:
# False
# False
# True

# %% [markdown]
# 10) Write a Python program that matches a word at the beginning of a string.

# %%
# Solution
def text_match(text):
  return re.search(r"^[A-Za-z]", text) != None

print(text_match("The quick brown fox jumps over the lazy dog."))  # Found a match!
print(text_match(" The quick brown fox jumps over the lazy dog."))  # Not matched
# Out:
# True
# False

# %% [markdown]
# 11) Write a Python program that matches a word at the end of string, with optional punctuation.

# %%
# Solution
def text_match(text):
  return re.search(r"[A-Za-z][.]?$", text) != None

print(text_match("The quick brown fox jumps over the lazy dog."))  # Found a match!
print(text_match("The quick brown fox jumps over the lazy dog. "))  # Not matched
print(text_match("The quick brown fox jumps over the lazy dog "))  # Not matched
# Out:
# False
# False
# False

# %% [markdown]
# 12) Write a Python program that matches a word containing 'z'

# %%
# Solution
def text_match(text):
  return re.search(r"\b\w*z\w*\b", text) != None

  
print(text_match("The quick brown fox jumps over the lazy dog."))  # Found a match!
print(text_match("Python Exercises."))  # Not matched
# Out:
# <re.Match object; span=(35, 39), match='lazy'>
# None

# %% [markdown]
# 13) Write a Python program that matches a word containing 'z', not at the start or end of the word.

# %%
# Solution
def text_match(text):
  return re.search(r"\b\w+z\w+\b", text) 

print(text_match("The quick brown fox jumps over the lazy dog."))  # Found a match!
print(text_match("Python Exercises."))  # Not matched
# Out:
# <re.Match object; span=(35, 39), match='lazy'>
# <re.Match object; span=(7, 12), match='zzoom'>

# %% [markdown]
# 14) Write a Python program to match a string that contains only upper and lowercase letters, numbers, and underscores.

# %%
# Solution
def text_match(text):
  return re.search(r"^\w+$", text) != None

print(text_match("The quick brown fox jumps over the lazy dog."))  # Not matched
print(text_match("Python_Exercises_1"))  # Found a match!
# Out:
# False
# True

# %% [markdown]
# 15) Write a Python program where a string will start with a specific number.

# %%
# Solution
def match_num(text):
  return re.search(r"^5", text) != None
  
print(match_num('5-2345861')) # True
print(match_num('6-2345861')) # False
# Out:
# True
# False

# %% [markdown]
# 16) Write a Python program to remove leading zeros from an IP address

# %%
# Solution
def rewrite_ip(ip):
  # your code here
  return re.sub(r"\.0", ".", ip)

ip = "216.08.094.196"
string = rewrite_ip(ip)
print(string) # 216.8.94.196
# Out:
# 216.8.94.196

# %% [markdown]
# 17) Write a Python program to check for a number at the end of a string.

# %%
# Solution
def end_num(text):
  a=6
  return re.search(rf"{a}", text)

print(end_num('abcdef'))  # False
print(end_num('abcdef6')) # True
# Out:
# None
# <re.Match object; span=(6, 7), match='6'>

# %% [markdown]
# 18) Write a Python program to search the numbers (0-9) of length between 1 to 3 in a given string.

# %%
# Solution
def print_digits(string):
  
  for x in re.findall(r"[0-9]{1,3}", string):
    print(x)

string = "Exercises number 1, 12, 13, and 345 are important"
print_digits(string)
# Number of length 1 to 3
# 1
# 12
# 13
# 345
# Out:
# 1
# 12
# 13
# 345

# %% [markdown]
# 19) Write a Python program to search some literals strings in a string.
# Sample text : 'The quick brown fox jumps over the lazy dog.'
# Searched words : 'fox', 'dog', 'horse'

# %%
# Solution
def print_match(patterns, text):
  for x in patterns:
    print(f"Serching for {x} in {text}")
    if re.search(x, text) != None:
      print("Matched!")
    else:
      print("Not Matched!")


patterns = [ 'fox', 'dog', 'horse' ]
text = 'The quick brown fox jumps over the lazy dog.'
print_match(patterns, text)
# Searching for "fox" in "The quick brown fox jumps over the lazy dog." ->
# Matched!
# Searching for "dog" in "The quick brown fox jumps over the lazy dog." ->
# Matched!
# Searching for "horse" in "The quick brown fox jumps over the lazy dog." ->
# Not Matched!
# Out:
# Serching for fox in The quick brown fox jumps over the lazy dog.
# Matched!
# Serching for dog in The quick brown fox jumps over the lazy dog.
# Matched!
# Serching for horse in The quick brown fox jumps over the lazy dog.
# Not Matched!

# %% [markdown]
# 20) Write a Python program to search a literals string in a string and also find the location within the original string where the pattern occurs
#
# Sample text : 'The quick brown fox jumps over the lazy dog.'
# Searched words : 'fox'

# %%
# Solution
def print_match_location(pattern, text):
  result = re.search(pattern, text)
  span1 = result.span()
  print(f'Found "{pattern}" in "{text}" from {span1[0]} to {span1[1]}')

pattern = 'fox'
text = 'The quick brown fox jumps over the lazy dog.'
print_match_location(pattern, text)
# Found "fox" in "The quick brown fox jumps over the lazy dog." from 16 to 19
# Out:
# Found "fox" in "The quick brown fox jumps over the lazy dog." from 16 to 19

# %% [markdown]
# 21) Write a Python program to find the substrings within a string.
#
# Sample text :
#
# 'Python exercises, PHP exercises, C# exercises'
#
# Pattern :
#
# 'exercises'
#
# Note: There are three instances of exercises in the input string.

# %%
# Solution
def find_all_matches(pattern, text):
  for x in re.findall(pattern,text):
    print(f"found {x}")

text = 'Python exercises, PHP exercises, C# exercises'
pattern = 'exercises'
find_all_matches(pattern, text)
# Found "exercises"
# Found "exercises"
# Found "exercises"
# Out:
# found exercises
# found exercises
# found exercises

# %% [markdown]
# 22) Write a Python program to find the occurrence and position of the substrings within a string.

# %%
# Solution
def find_all_matches_location(pattern, text):
    for x in re.finditer(pattern, text):
        #.finditer function return the terator yielding match objects
        # search function return match object but only 1st instance
        # find all function does not give match object, it gives list or tuple so we can not use span method
        span2 = x.span()
        print(f"found {pattern} at {span2[0]}:{span2[1]}")
  


text = 'Python exercises, PHP exercises, C# exercises'
pattern = 'exercises'
find_all_matches_location(pattern, text)
# Found "exercises" at 7:16
# Found "exercises" at 22:31
# Found "exercises" at 36:45
# Out:
# found exercises at 7:16
# found exercises at 22:31
# found exercises at 36:45

# %% [markdown]
# 23) Write a Python program to replace whitespaces with an underscore and vice versa.

# %%
text = 'Python Exercises'

# Your code
text = re.sub(" ","_",text)

print(text) # Python_Exercises


# Your code
text = re.sub("_"," ",text)
print(text) # Python Exercises
# Out:
# Python_Exercises
# Python Exercises

# %% [markdown]
# 24) Write a Python program to extract year, month and date from a an url.

# %%
# Solution
def extract_date(url):
  result= re.findall("/(\d{4})/(\d{2})/(\d{2})", url)
  #This is how you creat the group tuple with findall function
  return result
  
url1= "https://www.washingtonpost.com/news/football-insider/wp/2016/09/02/odell-beckhams-fame-rests-on-one-stupid-little-ball-josh-norman-tells-author/"
print(extract_date(url1)) # [('2016', '09', '02')]
# Out:
# [('2016', '09', '02')]

# %% [markdown]
# 25) Write a Python program to convert a date of yyyy-mm-dd format to dd-mm-yyyy format.

# %%
# Solution
def change_date_format(dt):
  result = re.findall(r"\d{2,4}", dt)
  return (f"{result[2]}-{result[1]}-{result[0]}")

dt1 = "2026-01-02"
print("Original date in YYYY-MM-DD Format: ",dt1)  # Original date in YYY-MM-DD Format:  2026-01-02
print("New date in DD-MM-YYYY Format: ",change_date_format(dt1))  # New date in DD-MM-YYYY Format:  02-01-2026
# Out:
# Original date in YYYY-MM-DD Format:  2026-01-02
# New date in DD-MM-YYYY Format:  02-01-2026

# %% [markdown]
# 26) Write a Python program to match if any words from a list of words starting with letter 'P'.

# %%
# Find better option.. Sample strings.
def print_words_starting_with_P(words):
    #for x in words:
    result = re.findall(r"(^P.*) (P[A-Za-z]*)", " ".join(words))
    print(result)
        
  

words = ["Python PHP", "Java JavaScript", "c c++"]
print_words_starting_with_P(words)  # ('Python', 'PHP')
# Out:
# [('Python', 'PHP')]

# %% [markdown]
# 27) Write a Python program to separate and print the numbers of a given string.

# %%
# Solution
def print_all_numbers(text):
  for x in re.findall(r'\d+',text):
    print(x)

# Sample string.
text = "Ten 10, Twenty 20, Thirty 30"
print_all_numbers(text)
# 10
# 20
# 30
# Out:
# 10
# 20
# 30

# %% [markdown]
# 28) Write a Python program to find all words starting with 'a' or 'e' in a given string.

# %%
# Solution
def get_all_words_containing_a_or_e(text):
  return re.findall(r'[ae]\w+',text)


# Input.
text = "The following example creates an ArrayList with a capacity of 50 elements. Four elements are then added to the ArrayList and the ArrayList is trimmed accordingly."
print(get_all_words_containing_a_or_e(text))
# ['example', 'eates', 'an', 'ayList', 'apacity', 'elements', 'elements', 'are', 'en', 'added', 'ayList', 'and', 'ayList', 'ed', 'accordingly']
# Out:
# ['example', 'eates', 'an', 'ayList', 'apacity', 'elements', 'elements', 'are', 'en', 'added', 'ayList', 'and', 'ayList', 'ed', 'accordingly']

# %% [markdown]
# 29) Write a Python program to separate and print the numbers and their position of a given string.

# %%
# Solution
def print_all_numbers_and_their_position(text):
   result = re.search(r'\d+', text )
   print(result.group())
   print(f"index postion: {result.span()[0]}")
    

# Input.
text = "The following example creates an ArrayList with a capacity of 50 elements. Four elements are then added to the ArrayList and the ArrayList is trimmed accordingly."
print_all_numbers_and_their_position(text)
# 50
# Index position: 62
# Out:
# 50
# index postion: 62

# %% [markdown]
# 30) Write a Python program to abbreviate 'Road' as 'Rd.' in a given string.

# %%
# Solution
def abbreviate_road(street):
  result = re.sub('Road','Rd',street)
  print(result)

street = '21 Ramkrishna Road'

print(abbreviate_road(street))  # 21 Ramkrishna Rd.
# Out:
# 21 Ramkrishna Rd
# None
